# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + "Boston"
print(city_url)
#city_weather=requests.get(city_url)
#boston_data = city_weather.json()
boston_data["weather"][0]["description"]
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e9737c04d4f4a60c66281ec6398e3b5f&q=Boston
# 'few clouds'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                  "Lat": city_lat,
                  "Lng": city_lng,
                  "Max Temp": city_max_temp,
                  "Humidity": city_humidity,
                  "Cloudiness": city_clouds,
                  "Wind Speed": city_wind,
                  "Country": city_country,
                  "Weather Description": city_description
                 })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | yinchuan
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | hambantota
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | la virginia
# Processing Record 9 of Set 1 | quelimane
# Processing Record 10 of Set 1 | clyde river
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | dillon
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | verkhnevilyuysk
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | inirida
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 1 | meulaboh
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | padang
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | namibe
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | wokha
# Processing Record 34 of Set 1 | bundaberg
# Processing Record 35 of Set 1 | arlit
# Processing Record 36 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | caravelas
# Processing Record 39 of Set 1 | ostrovnoy
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | guatire
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | awjilah
# Processing Record 44 of Set 1 | honiara
# Processing Record 45 of Set 1 | lorengau
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | bagdarin
# Processing Record 50 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | kopyevo
# City not found. Skipping...
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | hendek
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | cheremukhovo
# Processing Record 6 of Set 2 | plesetsk
# Processing Record 7 of Set 2 | port blair
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | sioux lookout
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | beisfjord
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | angoram
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 2 | vardo
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | dudinka
# Processing Record 22 of Set 2 | la rioja
# Processing Record 23 of Set 2 | palmer
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | shu
# Processing Record 27 of Set 2 | ca mau
# Processing Record 28 of Set 2 | myaundzha
# Processing Record 29 of Set 2 | boda
# Processing Record 30 of Set 2 | verkhoyansk
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | puerto baquerizo moreno
# Processing Record 33 of Set 2 | khani
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 37 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 2 | camana
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | mykhaylivka
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | atambua
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | yerbogachen
# Processing Record 47 of Set 2 | muroto
# Processing Record 48 of Set 2 | santo antonio do ica
# Processing Record 49 of Set 2 | margate
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | flin flon
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | chapais
# Processing Record 7 of Set 3 | cockburn town
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | sainte-rose
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | aasiaat
# Processing Record 12 of Set 3 | beloha
# Processing Record 13 of Set 3 | northam
# Processing Record 14 of Set 3 | georgiyevka
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | ustrzyki dolne
# Processing Record 18 of Set 3 | lucapa
# Processing Record 19 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 3 | pacific grove
# Processing Record 21 of Set 3 | singarayakonda
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | grand gaube
# Processing Record 24 of Set 3 | senmonorom
# City not found. Skipping...
# Processing Record 25 of Set 3 | mompos
# Processing Record 26 of Set 3 | sao gabriel da cachoeira
# Processing Record 27 of Set 3 | sarrebourg
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | provins
# Processing Record 31 of Set 3 | baculin
# Processing Record 32 of Set 3 | leningradskiy
# Processing Record 33 of Set 3 | brownwood
# Processing Record 34 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | orzhytsya
# Processing Record 37 of Set 3 | tsabong
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | tiarei
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | mattru
# Processing Record 42 of Set 3 | port alfred
# Processing Record 43 of Set 3 | jinxiang
# Processing Record 44 of Set 3 | opuwo
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | vila velha
# Processing Record 48 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | taltal
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | isla mujeres
# Processing Record 3 of Set 4 | hofn
# Processing Record 4 of Set 4 | volchikha
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | tazovskiy
# Processing Record 8 of Set 4 | la ronge
# Processing Record 9 of Set 4 | qaqortoq
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | vostok
# Processing Record 12 of Set 4 | bani walid
# Processing Record 13 of Set 4 | vestbygda
# City not found. Skipping...
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | tura
# Processing Record 19 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 4 | axim
# Processing Record 21 of Set 4 | kavaratti
# Processing Record 22 of Set 4 | mayo
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | whitianga
# Processing Record 28 of Set 4 | christchurch
# Processing Record 29 of Set 4 | maple creek
# Processing Record 30 of Set 4 | atherton
# Processing Record 31 of Set 4 | harper
# Processing Record 32 of Set 4 | gaoua
# Processing Record 33 of Set 4 | ossora
# Processing Record 34 of Set 4 | uglovskoye
# Processing Record 35 of Set 4 | roald
# Processing Record 36 of Set 4 | ouallam
# Processing Record 37 of Set 4 | misratah
# Processing Record 38 of Set 4 | sao joao da barra
# Processing Record 39 of Set 4 | qaanaaq
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | ancud
# Processing Record 42 of Set 4 | nioki
# Processing Record 43 of Set 4 | wanning
# Processing Record 44 of Set 4 | jiaozhou
# Processing Record 45 of Set 4 | mitsamiouli
# Processing Record 46 of Set 4 | toulepleu
# City not found. Skipping...
# Processing Record 47 of Set 4 | claveria
# Processing Record 48 of Set 4 | cayenne
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | roma
# Processing Record 1 of Set 5 | faanui
# Processing Record 2 of Set 5 | bilibino
# Processing Record 3 of Set 5 | saint-lo
# Processing Record 4 of Set 5 | pandharpur
# Processing Record 5 of Set 5 | coihaique
# Processing Record 6 of Set 5 | bilma
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | nome
# Processing Record 10 of Set 5 | emerald
# Processing Record 11 of Set 5 | mount gambier
# Processing Record 12 of Set 5 | shitanjing
# Processing Record 13 of Set 5 | tilichiki
# Processing Record 14 of Set 5 | alofi
# Processing Record 15 of Set 5 | synya
# Processing Record 16 of Set 5 | seda
# Processing Record 17 of Set 5 | gushikawa
# Processing Record 18 of Set 5 | yuancheng
# Processing Record 19 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 5 | bulaevo
# Processing Record 21 of Set 5 | nadym
# Processing Record 22 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 5 | altay
# Processing Record 24 of Set 5 | amarillo
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | sulangan
# Processing Record 27 of Set 5 | nouadhibou
# Processing Record 28 of Set 5 | tomatlan
# Processing Record 29 of Set 5 | sibolga
# Processing Record 30 of Set 5 | russell
# Processing Record 31 of Set 5 | cabo san lucas
# Processing Record 32 of Set 5 | iisalmi
# Processing Record 33 of Set 5 | thunder bay
# Processing Record 34 of Set 5 | herbeumont
# Processing Record 35 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | santa maria
# Processing Record 38 of Set 5 | ahtopol
# Processing Record 39 of Set 5 | farsund
# Processing Record 40 of Set 5 | zhaoyuan
# Processing Record 41 of Set 5 | kutum
# Processing Record 42 of Set 5 | staryy nadym
# Processing Record 43 of Set 5 | dingle
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | rio grande
# Processing Record 48 of Set 5 | karwar
# Processing Record 49 of Set 5 | kochubey
# Processing Record 50 of Set 5 | great yarmouth
# Processing Record 1 of Set 6 | syracuse
# Processing Record 2 of Set 6 | ndele
# Processing Record 3 of Set 6 | itacare
# Processing Record 4 of Set 6 | taree
# Processing Record 5 of Set 6 | tommot
# Processing Record 6 of Set 6 | semibratovo
# Processing Record 7 of Set 6 | coquimbo
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | saurimo
# Processing Record 10 of Set 6 | bonavista
# Processing Record 11 of Set 6 | gua musang
# Processing Record 12 of Set 6 | jala
# Processing Record 13 of Set 6 | luderitz
# Processing Record 14 of Set 6 | lotofaga
# Processing Record 15 of Set 6 | hamilton
# Processing Record 16 of Set 6 | udachnyy
# Processing Record 17 of Set 6 | krasnyy yar
# Processing Record 18 of Set 6 | tabuk
# Processing Record 19 of Set 6 | muros
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | druzhba
# Processing Record 22 of Set 6 | shibetsu
# Processing Record 23 of Set 6 | touros
# Processing Record 24 of Set 6 | bethanien
# Processing Record 25 of Set 6 | linxia
# Processing Record 26 of Set 6 | moindou
# Processing Record 27 of Set 6 | mehamn
# Processing Record 28 of Set 6 | leh
# Processing Record 29 of Set 6 | fortuna
# Processing Record 30 of Set 6 | onokhoy
# Processing Record 31 of Set 6 | casino
# Processing Record 32 of Set 6 | natal
# Processing Record 33 of Set 6 | mpraeso
# Processing Record 34 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 6 | vila franca do campo
# Processing Record 36 of Set 6 | derzhavinsk
# Processing Record 37 of Set 6 | veraval
# Processing Record 38 of Set 6 | illela
# Processing Record 39 of Set 6 | tynda
# Processing Record 40 of Set 6 | reyes
# Processing Record 41 of Set 6 | nanortalik
# Processing Record 42 of Set 6 | krasnoselkup
# Processing Record 43 of Set 6 | kazerun
# Processing Record 44 of Set 6 | klaksvik
# Processing Record 45 of Set 6 | kaeo
# Processing Record 46 of Set 6 | lukovetskiy
# Processing Record 47 of Set 6 | walvis bay
# Processing Record 48 of Set 6 | balclutha
# Processing Record 49 of Set 6 | sahuaripa
# Processing Record 50 of Set 6 | gigmoto
# Processing Record 1 of Set 7 | umm lajj
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | camacupa
# Processing Record 4 of Set 7 | arauca
# Processing Record 5 of Set 7 | evensk
# Processing Record 6 of Set 7 | eureka
# Processing Record 7 of Set 7 | konde
# Processing Record 8 of Set 7 | swanzey
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | victor harbor
# Processing Record 11 of Set 7 | nishihara
# Processing Record 12 of Set 7 | kattivakkam
# Processing Record 13 of Set 7 | berlevag
# Processing Record 14 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 15 of Set 7 | vilhena
# Processing Record 16 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 17 of Set 7 | lagos
# Processing Record 18 of Set 7 | duzce
# Processing Record 19 of Set 7 | praya
# Processing Record 20 of Set 7 | amazar
# Processing Record 21 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 7 | sakakah
# Processing Record 24 of Set 7 | porto tolle
# Processing Record 25 of Set 7 | saskylakh
# Processing Record 26 of Set 7 | petrove
# Processing Record 27 of Set 7 | torbay
# Processing Record 28 of Set 7 | sambava
# Processing Record 29 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 7 | lata
# Processing Record 31 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 7 | garwolin
# Processing Record 33 of Set 7 | mao
# Processing Record 34 of Set 7 | fort morgan
# Processing Record 35 of Set 7 | singleton
# Processing Record 36 of Set 7 | sherlovaya gora
# Processing Record 37 of Set 7 | kampot
# Processing Record 38 of Set 7 | nangwa
# Processing Record 39 of Set 7 | riohacha
# Processing Record 40 of Set 7 | umarkot
# Processing Record 41 of Set 7 | pangnirtung
# Processing Record 42 of Set 7 | champerico
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | sitka
# Processing Record 45 of Set 7 | levice
# Processing Record 46 of Set 7 | winnemucca
# Processing Record 47 of Set 7 | te anau
# Processing Record 48 of Set 7 | tenenkou
# Processing Record 49 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 7 | tahe
# Processing Record 1 of Set 8 | tateyama
# Processing Record 2 of Set 8 | jumla
# Processing Record 3 of Set 8 | khatanga
# Processing Record 4 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 8 | fort nelson
# Processing Record 6 of Set 8 | shache
# Processing Record 7 of Set 8 | henties bay
# Processing Record 8 of Set 8 | lazaro cardenas
# Processing Record 9 of Set 8 | vanimo
# Processing Record 10 of Set 8 | wanxian
# Processing Record 11 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 8 | tessalit
# Processing Record 13 of Set 8 | bethel
# Processing Record 14 of Set 8 | jacmel
# Processing Record 15 of Set 8 | adrar
# Processing Record 16 of Set 8 | luanda
# Processing Record 17 of Set 8 | lavrentiya
# Processing Record 18 of Set 8 | eyrarbakki
# Processing Record 19 of Set 8 | chit baragaon
# City not found. Skipping...
# Processing Record 20 of Set 8 | karratha
# Processing Record 21 of Set 8 | lugovoy
# Processing Record 22 of Set 8 | waipawa
# Processing Record 23 of Set 8 | havoysund
# Processing Record 24 of Set 8 | rovaniemi
# Processing Record 25 of Set 8 | atar
# Processing Record 26 of Set 8 | ugento
# Processing Record 27 of Set 8 | munak
# Processing Record 28 of Set 8 | naze
# Processing Record 29 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 8 | lahaina
# Processing Record 31 of Set 8 | san jose
# Processing Record 32 of Set 8 | sistranda
# Processing Record 33 of Set 8 | vao
# Processing Record 34 of Set 8 | parnu-jaagupi
# Processing Record 35 of Set 8 | yemelyanovo
# Processing Record 36 of Set 8 | pangody
# Processing Record 37 of Set 8 | isangel
# Processing Record 38 of Set 8 | mahebourg
# Processing Record 39 of Set 8 | chama
# Processing Record 40 of Set 8 | takoradi
# Processing Record 41 of Set 8 | joshimath
# Processing Record 42 of Set 8 | san pedro
# Processing Record 43 of Set 8 | praia
# Processing Record 44 of Set 8 | palana
# Processing Record 45 of Set 8 | suoyarvi
# Processing Record 46 of Set 8 | esil
# Processing Record 47 of Set 8 | olafsvik
# Processing Record 48 of Set 8 | sabang
# Processing Record 49 of Set 8 | lourdes
# Processing Record 50 of Set 8 | soyo
# Processing Record 1 of Set 9 | guanay
# Processing Record 2 of Set 9 | pierre
# Processing Record 3 of Set 9 | belmonte
# Processing Record 4 of Set 9 | tshikapa
# Processing Record 5 of Set 9 | trelew
# Processing Record 6 of Set 9 | kismayo
# Processing Record 7 of Set 9 | japura
# Processing Record 8 of Set 9 | kolimvari
# City not found. Skipping...
# Processing Record 9 of Set 9 | gat
# Processing Record 10 of Set 9 | oranjestad
# Processing Record 11 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 9 | challans
# Processing Record 13 of Set 9 | aitape
# Processing Record 14 of Set 9 | nantucket
# Processing Record 15 of Set 9 | sabha
# Processing Record 16 of Set 9 | sao paulo de olivenca
# Processing Record 17 of Set 9 | kununurra
# Processing Record 18 of Set 9 | lakes entrance
# Processing Record 19 of Set 9 | kulhudhuffushi
# Processing Record 20 of Set 9 | zholymbet
# Processing Record 21 of Set 9 | pisco
# Processing Record 22 of Set 9 | fairbanks
# Processing Record 23 of Set 9 | saldanha
# Processing Record 24 of Set 9 | svetlaya
# Processing Record 25 of Set 9 | boden
# Processing Record 26 of Set 9 | claremore
# Processing Record 27 of Set 9 | coachella
# Processing Record 28 of Set 9 | ust-maya
# Processing Record 29 of Set 9 | taoudenni
# Processing Record 30 of Set 9 | kavieng
# Processing Record 31 of Set 9 | nuuk
# Processing Record 32 of Set 9 | herre
# Processing Record 33 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 9 | micheweni
# Processing Record 35 of Set 9 | gladstone
# Processing Record 36 of Set 9 | port huron
# Processing Record 37 of Set 9 | nelson bay
# Processing Record 38 of Set 9 | key west
# Processing Record 39 of Set 9 | rocafuerte
# Processing Record 40 of Set 9 | helong
# Processing Record 41 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 9 | beringovskiy
# Processing Record 43 of Set 9 | torremolinos
# Processing Record 44 of Set 9 | tsurib
# Processing Record 45 of Set 9 | hasaki
# Processing Record 46 of Set 9 | yar-sale
# Processing Record 47 of Set 9 | codrington
# Processing Record 48 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 9 | nyurba
# Processing Record 50 of Set 9 | matagami
# Processing Record 1 of Set 10 | skjervoy
# Processing Record 2 of Set 10 | tabou
# Processing Record 3 of Set 10 | ambanja
# Processing Record 4 of Set 10 | camacha
# Processing Record 5 of Set 10 | yueyang
# Processing Record 6 of Set 10 | sungaipenuh
# Processing Record 7 of Set 10 | hobyo
# Processing Record 8 of Set 10 | srednekolymsk
# Processing Record 9 of Set 10 | cidreira
# Processing Record 10 of Set 10 | ponta delgada
# Processing Record 11 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 10 | kerrobert
# Processing Record 13 of Set 10 | guelengdeng
# City not found. Skipping...
# Processing Record 14 of Set 10 | fryanovo
# Processing Record 15 of Set 10 | pudozh
# Processing Record 16 of Set 10 | mahibadhoo
# Processing Record 17 of Set 10 | svetlogorsk
# Processing Record 18 of Set 10 | pontes e lacerda
# Processing Record 19 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 20 of Set 10 | innisfail
# Processing Record 21 of Set 10 | liling
# Processing Record 22 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 10 | ariquemes
# Processing Record 24 of Set 10 | balkanabat
# Processing Record 25 of Set 10 | xapuri
# Processing Record 26 of Set 10 | batagay
# Processing Record 27 of Set 10 | virbalis
# Processing Record 28 of Set 10 | tchibanga
# Processing Record 29 of Set 10 | lillooet
# Processing Record 30 of Set 10 | carutapera
# Processing Record 31 of Set 10 | san carlos de bariloche
# Processing Record 32 of Set 10 | sari
# Processing Record 33 of Set 10 | zemio
# Processing Record 34 of Set 10 | vaitape
# Processing Record 35 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 36 of Set 10 | buchanan
# Processing Record 37 of Set 10 | liverpool
# Processing Record 38 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 39 of Set 10 | zheleznodorozhnyy
# Processing Record 40 of Set 10 | kudahuvadhoo
# Processing Record 41 of Set 10 | santa isabel do rio negro
# Processing Record 42 of Set 10 | zhezkazgan
# Processing Record 43 of Set 10 | acapetahua
# Processing Record 44 of Set 10 | terrace
# Processing Record 45 of Set 10 | riyadh
# Processing Record 46 of Set 10 | chhachhrauli
# Processing Record 47 of Set 10 | green river
# Processing Record 48 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 10 | gayny
# Processing Record 1 of Set 11 | saint-francois
# Processing Record 2 of Set 11 | moose factory
# Processing Record 3 of Set 11 | navalmoral de la mata
# Processing Record 4 of Set 11 | granville
# Processing Record 5 of Set 11 | rupert
# Processing Record 6 of Set 11 | sinnamary
# Processing Record 7 of Set 11 | klyuchi
# Processing Record 8 of Set 11 | russkaya polyana
# Processing Record 9 of Set 11 | san cristobal
# Processing Record 10 of Set 11 | mahanoro
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | aflao
# Processing Record 13 of Set 11 | sasayama
# Processing Record 14 of Set 11 | faya
# Processing Record 15 of Set 11 | necochea
# Processing Record 16 of Set 11 | salina
# Processing Record 17 of Set 11 | carlsbad
# Processing Record 18 of Set 11 | dinghai
# Processing Record 19 of Set 11 | bahile
# Processing Record 20 of Set 11 | kalmunai
# Processing Record 21 of Set 11 | monrovia
# Processing Record 22 of Set 11 | mabaruma
# Processing Record 23 of Set 11 | rawson
# Processing Record 24 of Set 11 | cap malheureux
# Processing Record 25 of Set 11 | chulman
# Processing Record 26 of Set 11 | dali
# Processing Record 27 of Set 11 | murgab
# Processing Record 28 of Set 11 | campbell river
# Processing Record 29 of Set 11 | preeceville
# Processing Record 30 of Set 11 | charlestown
# Processing Record 31 of Set 11 | fethiye
# Processing Record 32 of Set 11 | batemans bay
# Processing Record 33 of Set 11 | kijang
# Processing Record 34 of Set 11 | zasheyek
# Processing Record 35 of Set 11 | paramonga
# Processing Record 36 of Set 11 | cizer
# Processing Record 37 of Set 11 | havelock
# Processing Record 38 of Set 11 | grand-santi
# Processing Record 39 of Set 11 | avila
# Processing Record 40 of Set 11 | komsomolskiy
# Processing Record 41 of Set 11 | saint-pierre
# Processing Record 42 of Set 11 | avera
# Processing Record 43 of Set 11 | svarstad
# Processing Record 44 of Set 11 | gilching
# Processing Record 45 of Set 11 | north battleford
# Processing Record 46 of Set 11 | port augusta
# Processing Record 47 of Set 11 | samarai
# Processing Record 48 of Set 11 | buckeye
# Processing Record 49 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 50 of Set 11 | kabanjahe
# Processing Record 1 of Set 12 | teahupoo
# Processing Record 2 of Set 12 | prestea
# Processing Record 3 of Set 12 | tuy hoa
# Processing Record 4 of Set 12 | iranshahr
# Processing Record 5 of Set 12 | debre birhan
# Processing Record 6 of Set 12 | qurayyat
# Processing Record 7 of Set 12 | hualmay
# Processing Record 8 of Set 12 | san joaquin
# Processing Record 9 of Set 12 | marsa matruh
# Processing Record 10 of Set 12 | manzanillo
# Processing Record 11 of Set 12 | manacapuru
# Processing Record 12 of Set 12 | nyuksenitsa
# Processing Record 13 of Set 12 | anzio
# Processing Record 14 of Set 12 | semey
# Processing Record 15 of Set 12 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 16 of Set 12 | forestville
# Processing Record 17 of Set 12 | zarand
# Processing Record 18 of Set 12 | bhatkal
# Processing Record 19 of Set 12 | bulembu
# Processing Record 20 of Set 12 | nioro
# Processing Record 21 of Set 12 | benjamin constant
# Processing Record 22 of Set 12 | saint-augustin
# Processing Record 23 of Set 12 | half moon bay
# Processing Record 24 of Set 12 | mkushi
# Processing Record 25 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 12 | vizinga
# Processing Record 27 of Set 12 | greensburg
# Processing Record 28 of Set 12 | anchorage
# Processing Record 29 of Set 12 | bharatpur
# Processing Record 30 of Set 12 | juneau
# Processing Record 31 of Set 12 | kieta
# Processing Record 32 of Set 12 | belaya gora
# Processing Record 33 of Set 12 | bonwapitse
# Processing Record 34 of Set 12 | bonthe
# Processing Record 35 of Set 12 | verbita
# Processing Record 36 of Set 12 | tacuarembo
# Processing Record 37 of Set 12 | plettenberg bay
# Processing Record 38 of Set 12 | ketchikan
# Processing Record 39 of Set 12 | petawawa
# Processing Record 40 of Set 12 | baiyin
# Processing Record 41 of Set 12 | coxim
# Processing Record 42 of Set 12 | virginia beach
# Processing Record 43 of Set 12 | meadow lake
# Processing Record 44 of Set 12 | tartus
# Processing Record 45 of Set 12 | urumqi
# Processing Record 46 of Set 12 | alexandria
# Processing Record 47 of Set 12 | buin
# Processing Record 48 of Set 12 | emmaus
# Processing Record 49 of Set 12 | aloleng
# Processing Record 50 of Set 12 | palasa
# Processing Record 1 of Set 13 | puerto suarez
# Processing Record 2 of Set 13 | dunedin
# Processing Record 3 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 13 | oyem
# Processing Record 5 of Set 13 | asfi
# Processing Record 6 of Set 13 | san nicolas
# Processing Record 7 of Set 13 | itaituba
# Processing Record 8 of Set 13 | ambilobe
# Processing Record 9 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | burnie
# Processing Record 11 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 12 of Set 13 | la libertad
# Processing Record 13 of Set 13 | severnoye
# Processing Record 14 of Set 13 | kokopo
# Processing Record 15 of Set 13 | kerur
# Processing Record 16 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 13 | muncar
# Processing Record 18 of Set 13 | warragul
# Processing Record 19 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 20 of Set 13 | kaptanganj
# Processing Record 21 of Set 13 | guane
# Processing Record 22 of Set 13 | tarko-sale
# Processing Record 23 of Set 13 | lafia
# Processing Record 24 of Set 13 | rocha
# Processing Record 25 of Set 13 | biak
# Processing Record 26 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 13 | bandarbeyla
# Processing Record 28 of Set 13 | bayanday
# Processing Record 29 of Set 13 | mercedes
# Processing Record 30 of Set 13 | sur
# Processing Record 31 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 13 | bulgan
# Processing Record 33 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 34 of Set 13 | calvia
# Processing Record 35 of Set 13 | praxedis guerrero
# Processing Record 36 of Set 13 | bull savanna
# Processing Record 37 of Set 13 | merauke
# Processing Record 38 of Set 13 | palauig
# Processing Record 39 of Set 13 | payyannur
# Processing Record 40 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 41 of Set 13 | los llanos de aridane
# Processing Record 42 of Set 13 | goundam
# Processing Record 43 of Set 13 | thabazimbi
# Processing Record 44 of Set 13 | port keats
# Processing Record 45 of Set 13 | manggar
# Processing Record 46 of Set 13 | wa
# City not found. Skipping...
# Processing Record 47 of Set 13 | roebourne
# Processing Record 48 of Set 13 | fez
# Processing Record 49 of Set 13 | batticaloa
# Processing Record 50 of Set 13 | leiyang
# Processing Record 1 of Set 14 | jiangyou
# Processing Record 2 of Set 14 | merritt
# Processing Record 3 of Set 14 | darhan
# Processing Record 4 of Set 14 | igra
# Processing Record 5 of Set 14 | portel
# Processing Record 6 of Set 14 | puerto carreno
# Processing Record 7 of Set 14 | havre-saint-pierre
# Processing Record 8 of Set 14 | kalach-na-donu
# Processing Record 9 of Set 14 | hoa binh
# Processing Record 10 of Set 14 | asilah
# Processing Record 11 of Set 14 | doka
# Processing Record 12 of Set 14 | baruun-urt
# Processing Record 13 of Set 14 | gueret
# Processing Record 14 of Set 14 | urusha
# Processing Record 15 of Set 14 | korla
# Processing Record 16 of Set 14 | erenhot
# Processing Record 17 of Set 14 | moron
# Processing Record 18 of Set 14 | lockhart
# Processing Record 19 of Set 14 | sorong
# Processing Record 20 of Set 14 | tete
# Processing Record 21 of Set 14 | tarakan
# Processing Record 22 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 14 | gamba
# Processing Record 24 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 25 of Set 14 | pochutla
# Processing Record 26 of Set 14 | cienfuegos
# Processing Record 27 of Set 14 | mocuba
# Processing Record 28 of Set 14 | san matias
# Processing Record 29 of Set 14 | goya
# Processing Record 30 of Set 14 | maragogi
# Processing Record 31 of Set 14 | progreso
# Processing Record 32 of Set 14 | bairiki
# Processing Record 33 of Set 14 | paytug
# City not found. Skipping...
# Processing Record 34 of Set 14 | mackay
# Processing Record 35 of Set 14 | marsh harbour
# Processing Record 36 of Set 14 | lipetsk
# Processing Record 37 of Set 14 | zaqatala
# Processing Record 38 of Set 14 | kassala
# Processing Record 39 of Set 14 | san lawrenz
# Processing Record 40 of Set 14 | dhidhdhoo
# Processing Record 41 of Set 14 | noumea
# Processing Record 42 of Set 14 | alta floresta
# Processing Record 43 of Set 14 | sharjah
# Processing Record 44 of Set 14 | hailar
# Processing Record 45 of Set 14 | tecoanapa
# Processing Record 46 of Set 14 | college
# Processing Record 47 of Set 14 | weligama
# Processing Record 48 of Set 14 | gonbad-e qabus
# Processing Record 49 of Set 14 | zharkent
# Processing Record 50 of Set 14 | deep river
# Processing Record 1 of Set 15 | mountain home
# Processing Record 2 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 3 of Set 15 | batagay-alyta
# Processing Record 4 of Set 15 | biloela
# Processing Record 5 of Set 15 | minab
# Processing Record 6 of Set 15 | khandyga
# Processing Record 7 of Set 15 | richards bay
# Processing Record 8 of Set 15 | aguadilla
# Processing Record 9 of Set 15 | port macquarie
# Processing Record 10 of Set 15 | svetlyy
# Processing Record 11 of Set 15 | ahuimanu
# Processing Record 12 of Set 15 | yatou
# Processing Record 13 of Set 15 | igarka
# Processing Record 14 of Set 15 | antalaha
# Processing Record 15 of Set 15 | ostroleka
# Processing Record 16 of Set 15 | sorland
# Processing Record 17 of Set 15 | ixtapa
# Processing Record 18 of Set 15 | gursarai
# Processing Record 19 of Set 15 | viedma
# Processing Record 20 of Set 15 | lompoc
# Processing Record 21 of Set 15 | agboville
# Processing Record 22 of Set 15 | botou
# Processing Record 23 of Set 15 | cabedelo
# Processing Record 24 of Set 15 | coahuayana
# Processing Record 25 of Set 15 | port moresby
# Processing Record 26 of Set 15 | trairi
# Processing Record 27 of Set 15 | rockhampton
# Processing Record 28 of Set 15 | acuna
# City not found. Skipping...
# Processing Record 29 of Set 15 | amahai
# Processing Record 30 of Set 15 | sao filipe
# Processing Record 31 of Set 15 | dongying
# Processing Record 32 of Set 15 | pandan
# Processing Record 33 of Set 15 | langham
# Processing Record 34 of Set 15 | beyneu
# Processing Record 35 of Set 15 | chabahar
# Processing Record 36 of Set 15 | oranjemund
# Processing Record 37 of Set 15 | jiexiu
# Processing Record 38 of Set 15 | boromo
# Processing Record 39 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 40 of Set 15 | nebolchi
# Processing Record 41 of Set 15 | gwadar
# Processing Record 42 of Set 15 | silikatnyy
# Processing Record 43 of Set 15 | ternate
# Processing Record 44 of Set 15 | cabra
# Processing Record 45 of Set 15 | ewo
# Processing Record 46 of Set 15 | graham
# Processing Record 47 of Set 15 | gasa
# Processing Record 48 of Set 15 | ust-kuyga
# Processing Record 49 of Set 15 | lloydminster
# Processing Record 50 of Set 15 | labuan
# Processing Record 1 of Set 16 | a
# City not found. Skipping...
# Processing Record 2 of Set 16 | karaton
# Processing Record 3 of Set 16 | athens
# Processing Record 4 of Set 16 | the valley
# Processing Record 5 of Set 16 | teya
# Processing Record 6 of Set 16 | aksu
# Processing Record 7 of Set 16 | aojiang
# Processing Record 8 of Set 16 | channel-port aux basques
# Processing Record 9 of Set 16 | hami
# Processing Record 10 of Set 16 | gonaives
# Processing Record 11 of Set 16 | port hardy
# Processing Record 12 of Set 16 | gorin
# Processing Record 13 of Set 16 | kumphawapi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tasiilaq  65.6145  -37.6368     11.07        81          99
# 1        Yinchuan  38.4681  106.2731     20.98        32           4
# 2        Hermanus -34.4187   19.2345     66.79        95          64
# 3           Vaini -21.2000 -175.2000     77.16        94         100
# 4         Rikitea -23.1203 -134.9692     75.49        79           5
# 5      Hambantota   6.1241   81.1185     70.14       100          20
# 6  Saint-Philippe -21.3585   55.7679     72.99        85          20
# 7     La Virginia   4.8997  -75.8825     71.15        82          20
# 8       Quelimane -17.8786   36.8883     76.95        94          20
# 9     Clyde River  70.4692  -68.5914     -0.17        85         100
#
#    Wind Speed Country Weather Description
# 0        5.79      GL     overcast clouds
# 1        5.88      CN           clear sky
# 2        5.61      ZA          light rain
# 3       13.80      TO       moderate rain
# 4       21.88      PF           clear sky
# 5        3.44      LK          few clouds
# 6        9.42      RE          light rain
# 7        5.75      CO          few clouds
# 8        2.30      MZ          few clouds
# 9        4.61      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df.rename(columns={"Weather Description":"Current Description"},inplace=True)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tasiilaq      GL  65.6145  -37.6368     11.07        81          99
# 1        Yinchuan      CN  38.4681  106.2731     20.98        32           4
# 2        Hermanus      ZA -34.4187   19.2345     66.79        95          64
# 3           Vaini      TO -21.2000 -175.2000     77.16        94         100
# 4         Rikitea      PF -23.1203 -134.9692     75.49        79           5
# 5      Hambantota      LK   6.1241   81.1185     70.14       100          20
# 6  Saint-Philippe      RE -21.3585   55.7679     72.99        85          20
# 7     La Virginia      CO   4.8997  -75.8825     71.15        82          20
# 8       Quelimane      MZ -17.8786   36.8883     76.95        94          20
# 9     Clyde River      CA  70.4692  -68.5914     -0.17        85         100
#
#    Wind Speed Current Description
# 0        5.79     overcast clouds
# 1        5.88           clear sky
# 2        5.61          light rain
# 3       13.80       moderate rain
# 4       21.88           clear sky
# 5        3.44          few clouds
# 6        9.42          light rain
# 7        5.75          few clouds
# 8        2.30          few clouds
# 9        4.61     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
